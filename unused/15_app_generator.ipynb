# %% [markdown]
# # Coding Assistant

# %%
# %pip install -r requirements.txt
# Out:
# Requirement already satisfied: langchain>=0.1.9 in ./env/lib/python3.11/site-packages (from -r requirements.txt (line 1)) (0.1.12)
# Requirement already satisfied: langgraph>=0.0.26 in ./env/lib/python3.11/site-packages (from -r requirements.txt (line 2)) (0.0.28)
# Requirement already satisfied: pydantic>=2.0.0 in ./env/lib/python3.11/site-packages (from -r requirements.txt (line 3)) (2.6.4)
# Requirement already satisfied: tavily-python in ./env/lib/python3.11/site-packages (from -r requirements.txt (line 4)) (0.3.1)
# Requirement already satisfied: langchain-openai>=0.0.2 in ./env/lib/python3.11/site-packages (from -r requirements.txt (line 5)) (0.0.8)
# Requirement already satisfied: langchainhub in ./env/lib/python3.11/site-packages (from -r requirements.txt (line 6)) (0.1.15)
# Requirement already satisfied: langchain_community>=0.0.27 in ./env/lib/python3.11/site-packages (from -r requirements.txt (line 7)) (0.0.28)
# Requirement already satisfied: langchain-cli in ./env/lib/python3.11/site-packages (from -r requirements.txt (line 8)) (0.0.21)
# Requirement already satisfied: langserve[all] in ./env/lib/python3.11/site-packages (from -r requirements.txt (line 9)) (0.0.46)
# Requirement already satisfied: openai in ./env/lib/python3.11/site-packages (from -r requirements.txt (line 10)) (1.13.3)
# Requirement already satisfied: python-dotenv in ./env/lib/python3.11/site-packages (from -r requirements.txt (line 11)) (1.0.1)
# Requirement already satisfied: google-search-results in ./env/lib/python3.11/site-packages (from -r requirements.txt (line 12)) (2.4.2)
# Requirement already satisfied: faiss-cpu in ./env/lib/python3.11/site-packages (from -r requirements.txt (line 13)) (1.8.0)
# Requirement already satisfied: pypdf in ./env/lib/python3.11/site-packages (from -r requirements.txt (line 14)) (4.1.0)
# Requirement already satisfied: tqdm in ./env/lib/python3.11/site-packages (from -r requirements.txt (line 15)) (4.66.2)
# Requirement already satisfied: wikipedia in ./env/lib/python3.11/site-packages (from -r requirements.txt (line 16)) (1.4.0)
# Requirement already satisfied: arxiv in ./env/lib/python3.11/site-packages (from -r requirements.txt (line 17)) (2.1.0)
# Requirement already satisfied: atlassian-python-api in ./env/lib/python3.11/site-packages (from -r requirements.txt (line 18)) (3.41.11)
# Requirement already satisfied: numexpr in ./env/lib/python3.11/site-packages (from -r requirements.txt (line 19)) (2.9.0)
# Requirement already satisfied: beautifulsoup4 in ./env/lib/python3.11/site-packages (from -r requirements.txt (line 20)) (4.12.3)
# Requirement already satisfied: lxml in ./env/lib/python3.11/site-packages (from -r requirements.txt (line 21)) (5.1.0)
# Requirement already satisfied: tiktoken in ./env/lib/python3.11/site-packages (from -r requirements.txt (line 22)) (0.6.0)
# Requirement already satisfied: ipydatagrid in ./env/lib/python3.11/site-packages (from -r requirements.txt (line 23)) (1.2.1)
# Requirement already satisfied: bqplot in ./env/lib/python3.11/site-packages (from -r requirements.txt (line 24)) (0.12.43)
# Requirement already satisfied: nbstripout in ./env/lib/python3.11/site-packages (from -r requirements.txt (line 25)) (0.7.1)
# Requirement already satisfied: duckduckgo-search in ./env/lib/python3.11/site-packages (from -r requirements.txt (line 26)) (5.0)
# Requirement already satisfied: pre-commit in ./env/lib/python3.11/site-packages (from -r requirements.txt (line 27)) (3.6.2)
# Collecting nbdime
#   Downloading nbdime-4.0.1-py3-none-any.whl (5.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 12.1 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: PyYAML>=5.3 in ./env/lib/python3.11/site-packages (from langchain>=0.1.9->-r requirements.txt (line 1)) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in ./env/lib/python3.11/site-packages (from langchain>=0.1.9->-r requirements.txt (line 1)) (2.0.28)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in ./env/lib/python3.11/site-packages (from langchain>=0.1.9->-r requirements.txt (line 1)) (3.9.3)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in ./env/lib/python3.11/site-packages (from langchain>=0.1.9->-r requirements.txt (line 1)) (0.6.4)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in ./env/lib/python3.11/site-packages (from langchain>=0.1.9->-r requirements.txt (line 1)) (1.33)
# Requirement already satisfied: langchain-core<0.2.0,>=0.1.31 in ./env/lib/python3.11/site-packages (from langchain>=0.1.9->-r requirements.txt (line 1)) (0.1.31)
# Requirement already satisfied: langchain-text-splitters<0.1,>=0.0.1 in ./env/lib/python3.11/site-packages (from langchain>=0.1.9->-r requirements.txt (line 1)) (0.0.1)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in ./env/lib/python3.11/site-packages (from langchain>=0.1.9->-r requirements.txt (line 1)) (0.1.24)
# Requirement already satisfied: numpy<2,>=1 in ./env/lib/python3.11/site-packages (from langchain>=0.1.9->-r requirements.txt (line 1)) (1.26.4)
# Requirement already satisfied: requests<3,>=2 in ./env/lib/python3.11/site-packages (from langchain>=0.1.9->-r requirements.txt (line 1)) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in ./env/lib/python3.11/site-packages (from langchain>=0.1.9->-r requirements.txt (line 1)) (8.2.3)
# Requirement already satisfied: annotated-types>=0.4.0 in ./env/lib/python3.11/site-packages (from pydantic>=2.0.0->-r requirements.txt (line 3)) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in ./env/lib/python3.11/site-packages (from pydantic>=2.0.0->-r requirements.txt (line 3)) (2.16.3)
# Requirement already satisfied: typing-extensions>=4.6.1 in ./env/lib/python3.11/site-packages (from pydantic>=2.0.0->-r requirements.txt (line 3)) (4.10.0)
# Collecting tiktoken
#   Using cached tiktoken-0.5.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
# Requirement already satisfied: regex>=2022.1.18 in ./env/lib/python3.11/site-packages (from tiktoken->-r requirements.txt (line 22)) (2023.12.25)
# Requirement already satisfied: types-requests<3.0.0.0,>=2.31.0.2 in ./env/lib/python3.11/site-packages (from langchainhub->-r requirements.txt (line 6)) (2.31.0.20240218)
# Requirement already satisfied: gitpython<4.0.0,>=3.1.40 in ./env/lib/python3.11/site-packages (from langchain-cli->-r requirements.txt (line 8)) (3.1.42)
# Requirement already satisfied: tomlkit<0.13.0,>=0.12.2 in ./env/lib/python3.11/site-packages (from langchain-cli->-r requirements.txt (line 8)) (0.12.4)
# Requirement already satisfied: typer[all]<0.10.0,>=0.9.0 in ./env/lib/python3.11/site-packages (from langchain-cli->-r requirements.txt (line 8)) (0.9.0)
# Requirement already satisfied: uvicorn<0.24.0,>=0.23.2 in ./env/lib/python3.11/site-packages (from langchain-cli->-r requirements.txt (line 8)) (0.23.2)
# Requirement already satisfied: fastapi<1,>=0.90.1 in ./env/lib/python3.11/site-packages (from langserve[all]->-r requirements.txt (line 9)) (0.110.0)
# Requirement already satisfied: httpx>=0.23.0 in ./env/lib/python3.11/site-packages (from langserve[all]->-r requirements.txt (line 9)) (0.27.0)
# Requirement already satisfied: httpx-sse>=0.3.1 in ./env/lib/python3.11/site-packages (from langserve[all]->-r requirements.txt (line 9)) (0.4.0)
# Requirement already satisfied: orjson>=2 in ./env/lib/python3.11/site-packages (from langserve[all]->-r requirements.txt (line 9)) (3.9.15)
# Requirement already satisfied: sse-starlette<2.0.0,>=1.3.0 in ./env/lib/python3.11/site-packages (from langserve[all]->-r requirements.txt (line 9)) (1.8.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in ./env/lib/python3.11/site-packages (from openai->-r requirements.txt (line 10)) (4.3.0)
# Requirement already satisfied: distro<2,>=1.7.0 in ./env/lib/python3.11/site-packages (from openai->-r requirements.txt (line 10)) (1.9.0)
# Requirement already satisfied: sniffio in ./env/lib/python3.11/site-packages (from openai->-r requirements.txt (line 10)) (1.3.1)
# Requirement already satisfied: feedparser==6.0.10 in ./env/lib/python3.11/site-packages (from arxiv->-r requirements.txt (line 17)) (6.0.10)
# Requirement already satisfied: sgmllib3k in ./env/lib/python3.11/site-packages (from feedparser==6.0.10->arxiv->-r requirements.txt (line 17)) (1.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./env/lib/python3.11/site-packages (from requests<3,>=2->langchain>=0.1.9->-r requirements.txt (line 1)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in ./env/lib/python3.11/site-packages (from requests<3,>=2->langchain>=0.1.9->-r requirements.txt (line 1)) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./env/lib/python3.11/site-packages (from requests<3,>=2->langchain>=0.1.9->-r requirements.txt (line 1)) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in ./env/lib/python3.11/site-packages (from requests<3,>=2->langchain>=0.1.9->-r requirements.txt (line 1)) (2024.2.2)
# Requirement already satisfied: deprecated in ./env/lib/python3.11/site-packages (from atlassian-python-api->-r requirements.txt (line 18)) (1.2.14)
# Requirement already satisfied: six in ./env/lib/python3.11/site-packages (from atlassian-python-api->-r requirements.txt (line 18)) (1.16.0)
# Requirement already satisfied: oauthlib in ./env/lib/python3.11/site-packages (from atlassian-python-api->-r requirements.txt (line 18)) (3.2.2)
# Requirement already satisfied: requests-oauthlib in ./env/lib/python3.11/site-packages (from atlassian-python-api->-r requirements.txt (line 18)) (1.3.1)
# Requirement already satisfied: jmespath in ./env/lib/python3.11/site-packages (from atlassian-python-api->-r requirements.txt (line 18)) (1.0.1)
# Requirement already satisfied: soupsieve>1.2 in ./env/lib/python3.11/site-packages (from beautifulsoup4->-r requirements.txt (line 20)) (2.5)
# Requirement already satisfied: ipywidgets<9,>=7.6 in ./env/lib/python3.11/site-packages (from ipydatagrid->-r requirements.txt (line 23)) (8.1.2)
# Requirement already satisfied: pandas>=1.3.5 in ./env/lib/python3.11/site-packages (from ipydatagrid->-r requirements.txt (line 23)) (2.2.1)
# Requirement already satisfied: py2vega>=0.5 in ./env/lib/python3.11/site-packages (from ipydatagrid->-r requirements.txt (line 23)) (0.6.1)
# Requirement already satisfied: traitlets>=4.3.0 in ./env/lib/python3.11/site-packages (from bqplot->-r requirements.txt (line 24)) (5.14.1)
# Requirement already satisfied: traittypes>=0.0.6 in ./env/lib/python3.11/site-packages (from bqplot->-r requirements.txt (line 24)) (0.2.1)
# Requirement already satisfied: nbformat in ./env/lib/python3.11/site-packages (from nbstripout->-r requirements.txt (line 25)) (5.9.2)
# Requirement already satisfied: click>=8.1.7 in ./env/lib/python3.11/site-packages (from duckduckgo-search->-r requirements.txt (line 26)) (8.1.7)
# Requirement already satisfied: curl-cffi>=0.6.2 in ./env/lib/python3.11/site-packages (from duckduckgo-search->-r requirements.txt (line 26)) (0.6.2)
# Requirement already satisfied: cfgv>=2.0.0 in ./env/lib/python3.11/site-packages (from pre-commit->-r requirements.txt (line 27)) (3.4.0)
# Requirement already satisfied: identify>=1.0.0 in ./env/lib/python3.11/site-packages (from pre-commit->-r requirements.txt (line 27)) (2.5.35)
# Requirement already satisfied: nodeenv>=0.11.1 in ./env/lib/python3.11/site-packages (from pre-commit->-r requirements.txt (line 27)) (1.8.0)
# Requirement already satisfied: virtualenv>=20.10.0 in ./env/lib/python3.11/site-packages (from pre-commit->-r requirements.txt (line 27)) (20.25.1)
# Requirement already satisfied: colorama in ./env/lib/python3.11/site-packages (from nbdime->-r requirements.txt (line 28)) (0.4.6)
# Requirement already satisfied: jinja2>=2.9 in ./env/lib/python3.11/site-packages (from nbdime->-r requirements.txt (line 28)) (3.1.3)
# Collecting jupyter-server
#   Downloading jupyter_server-2.13.0-py3-none-any.whl (383 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 383.2/383.2 kB 15.4 MB/s eta 0:00:00
# Collecting jupyter-server-mathjax>=0.2.2
#   Downloading jupyter_server_mathjax-0.2.6-py3-none-any.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 16.7 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: pygments in ./env/lib/python3.11/site-packages (from nbdime->-r requirements.txt (line 28)) (2.17.2)
# Requirement already satisfied: tornado in ./env/lib/python3.11/site-packages (from nbdime->-r requirements.txt (line 28)) (6.4)
# Requirement already satisfied: aiosignal>=1.1.2 in ./env/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain>=0.1.9->-r requirements.txt (line 1)) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in ./env/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain>=0.1.9->-r requirements.txt (line 1)) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in ./env/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain>=0.1.9->-r requirements.txt (line 1)) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./env/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain>=0.1.9->-r requirements.txt (line 1)) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in ./env/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain>=0.1.9->-r requirements.txt (line 1)) (1.9.4)
# Requirement already satisfied: cffi>=1.12.0 in ./env/lib/python3.11/site-packages (from curl-cffi>=0.6.2->duckduckgo-search->-r requirements.txt (line 26)) (1.16.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in ./env/lib/python3.11/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain>=0.1.9->-r requirements.txt (line 1)) (3.21.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in ./env/lib/python3.11/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain>=0.1.9->-r requirements.txt (line 1)) (0.9.0)
# Requirement already satisfied: starlette<0.37.0,>=0.36.3 in ./env/lib/python3.11/site-packages (from fastapi<1,>=0.90.1->langserve[all]->-r requirements.txt (line 9)) (0.36.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in ./env/lib/python3.11/site-packages (from gitpython<4.0.0,>=3.1.40->langchain-cli->-r requirements.txt (line 8)) (4.0.11)
# Requirement already satisfied: httpcore==1.* in ./env/lib/python3.11/site-packages (from httpx>=0.23.0->langserve[all]->-r requirements.txt (line 9)) (1.0.4)
# Requirement already satisfied: h11<0.15,>=0.13 in ./env/lib/python3.11/site-packages (from httpcore==1.*->httpx>=0.23.0->langserve[all]->-r requirements.txt (line 9)) (0.14.0)
# Requirement already satisfied: comm>=0.1.3 in ./env/lib/python3.11/site-packages (from ipywidgets<9,>=7.6->ipydatagrid->-r requirements.txt (line 23)) (0.2.1)
# Requirement already satisfied: ipython>=6.1.0 in ./env/lib/python3.11/site-packages (from ipywidgets<9,>=7.6->ipydatagrid->-r requirements.txt (line 23)) (8.22.2)
# Requirement already satisfied: widgetsnbextension~=4.0.10 in ./env/lib/python3.11/site-packages (from ipywidgets<9,>=7.6->ipydatagrid->-r requirements.txt (line 23)) (4.0.10)
# Requirement already satisfied: jupyterlab-widgets~=3.0.10 in ./env/lib/python3.11/site-packages (from ipywidgets<9,>=7.6->ipydatagrid->-r requirements.txt (line 23)) (3.0.10)
# Requirement already satisfied: MarkupSafe>=2.0 in ./env/lib/python3.11/site-packages (from jinja2>=2.9->nbdime->-r requirements.txt (line 28)) (2.1.5)
# Requirement already satisfied: jsonpointer>=1.9 in ./env/lib/python3.11/site-packages (from jsonpatch<2.0,>=1.33->langchain>=0.1.9->-r requirements.txt (line 1)) (2.4)
# Collecting argon2-cffi
#   Downloading argon2_cffi-23.1.0-py3-none-any.whl (15 kB)
# Requirement already satisfied: jupyter-client>=7.4.4 in ./env/lib/python3.11/site-packages (from jupyter-server->nbdime->-r requirements.txt (line 28)) (8.6.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in ./env/lib/python3.11/site-packages (from jupyter-server->nbdime->-r requirements.txt (line 28)) (5.7.1)
# Collecting jupyter-events>=0.9.0
#   Downloading jupyter_events-0.9.1-py3-none-any.whl (18 kB)
# Collecting jupyter-server-terminals
#   Downloading jupyter_server_terminals-0.5.3-py3-none-any.whl (13 kB)
# Requirement already satisfied: nbconvert>=6.4.4 in ./env/lib/python3.11/site-packages (from jupyter-server->nbdime->-r requirements.txt (line 28)) (7.16.2)
# Requirement already satisfied: overrides in ./env/lib/python3.11/site-packages (from jupyter-server->nbdime->-r requirements.txt (line 28)) (7.7.0)
# Requirement already satisfied: packaging in ./env/lib/python3.11/site-packages (from jupyter-server->nbdime->-r requirements.txt (line 28)) (23.2)
# Collecting prometheus-client
#   Downloading prometheus_client-0.20.0-py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 3.5 MB/s eta 0:00:00
# Requirement already satisfied: pyzmq>=24 in ./env/lib/python3.11/site-packages (from jupyter-server->nbdime->-r requirements.txt (line 28)) (25.1.2)
# Collecting send2trash>=1.8.2
#   Downloading Send2Trash-1.8.2-py3-none-any.whl (18 kB)
# Collecting terminado>=0.8.3
#   Downloading terminado-0.18.1-py3-none-any.whl (14 kB)
# Requirement already satisfied: websocket-client in ./env/lib/python3.11/site-packages (from jupyter-server->nbdime->-r requirements.txt (line 28)) (1.7.0)
# Requirement already satisfied: fastjsonschema in ./env/lib/python3.11/site-packages (from nbformat->nbstripout->-r requirements.txt (line 25)) (2.19.1)
# Requirement already satisfied: jsonschema>=2.6 in ./env/lib/python3.11/site-packages (from nbformat->nbstripout->-r requirements.txt (line 25)) (4.21.1)
# Requirement already satisfied: setuptools in ./env/lib/python3.11/site-packages (from nodeenv>=0.11.1->pre-commit->-r requirements.txt (line 27)) (65.5.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./env/lib/python3.11/site-packages (from pandas>=1.3.5->ipydatagrid->-r requirements.txt (line 23)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./env/lib/python3.11/site-packages (from pandas>=1.3.5->ipydatagrid->-r requirements.txt (line 23)) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in ./env/lib/python3.11/site-packages (from pandas>=1.3.5->ipydatagrid->-r requirements.txt (line 23)) (2024.1)
# Requirement already satisfied: gast<0.5,>=0.4.0 in ./env/lib/python3.11/site-packages (from py2vega>=0.5->ipydatagrid->-r requirements.txt (line 23)) (0.4.0)
# Requirement already satisfied: greenlet!=0.4.17 in ./env/lib/python3.11/site-packages (from SQLAlchemy<3,>=1.4->langchain>=0.1.9->-r requirements.txt (line 1)) (3.0.3)
# Requirement already satisfied: shellingham<2.0.0,>=1.3.0 in ./env/lib/python3.11/site-packages (from typer[all]<0.10.0,>=0.9.0->langchain-cli->-r requirements.txt (line 8)) (1.5.4)
# Requirement already satisfied: rich<14.0.0,>=10.11.0 in ./env/lib/python3.11/site-packages (from typer[all]<0.10.0,>=0.9.0->langchain-cli->-r requirements.txt (line 8)) (13.7.1)
# Requirement already satisfied: distlib<1,>=0.3.7 in ./env/lib/python3.11/site-packages (from virtualenv>=20.10.0->pre-commit->-r requirements.txt (line 27)) (0.3.8)
# Requirement already satisfied: filelock<4,>=3.12.2 in ./env/lib/python3.11/site-packages (from virtualenv>=20.10.0->pre-commit->-r requirements.txt (line 27)) (3.13.1)
# Requirement already satisfied: platformdirs<5,>=3.9.1 in ./env/lib/python3.11/site-packages (from virtualenv>=20.10.0->pre-commit->-r requirements.txt (line 27)) (4.2.0)
# Requirement already satisfied: wrapt<2,>=1.10 in ./env/lib/python3.11/site-packages (from deprecated->atlassian-python-api->-r requirements.txt (line 18)) (1.16.0)
# Requirement already satisfied: pycparser in ./env/lib/python3.11/site-packages (from cffi>=1.12.0->curl-cffi>=0.6.2->duckduckgo-search->-r requirements.txt (line 26)) (2.21)
# Requirement already satisfied: smmap<6,>=3.0.1 in ./env/lib/python3.11/site-packages (from gitdb<5,>=4.0.1->gitpython<4.0.0,>=3.1.40->langchain-cli->-r requirements.txt (line 8)) (5.0.1)
# Requirement already satisfied: decorator in ./env/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6->ipydatagrid->-r requirements.txt (line 23)) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in ./env/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6->ipydatagrid->-r requirements.txt (line 23)) (0.19.1)
# Requirement already satisfied: matplotlib-inline in ./env/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6->ipydatagrid->-r requirements.txt (line 23)) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in ./env/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6->ipydatagrid->-r requirements.txt (line 23)) (3.0.43)
# Requirement already satisfied: stack-data in ./env/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6->ipydatagrid->-r requirements.txt (line 23)) (0.6.3)
# Requirement already satisfied: pexpect>4.3 in ./env/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6->ipydatagrid->-r requirements.txt (line 23)) (4.9.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in ./env/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat->nbstripout->-r requirements.txt (line 25)) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in ./env/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat->nbstripout->-r requirements.txt (line 25)) (0.33.0)
# Requirement already satisfied: rpds-py>=0.7.1 in ./env/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat->nbstripout->-r requirements.txt (line 25)) (0.18.0)
# Collecting python-json-logger>=2.0.4
#   Downloading python_json_logger-2.0.7-py3-none-any.whl (8.1 kB)
# Collecting rfc3339-validator
#   Downloading rfc3339_validator-0.1.4-py2.py3-none-any.whl (3.5 kB)
# Collecting rfc3986-validator>=0.1.1
#   Downloading rfc3986_validator-0.1.1-py2.py3-none-any.whl (4.2 kB)
# Requirement already satisfied: bleach!=5.0.0 in ./env/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server->nbdime->-r requirements.txt (line 28)) (6.1.0)
# Requirement already satisfied: defusedxml in ./env/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server->nbdime->-r requirements.txt (line 28)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in ./env/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server->nbdime->-r requirements.txt (line 28)) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in ./env/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server->nbdime->-r requirements.txt (line 28)) (3.0.2)
# Requirement already satisfied: nbclient>=0.5.0 in ./env/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server->nbdime->-r requirements.txt (line 28)) (0.9.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in ./env/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server->nbdime->-r requirements.txt (line 28)) (1.5.1)
# Requirement already satisfied: tinycss2 in ./env/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server->nbdime->-r requirements.txt (line 28)) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./env/lib/python3.11/site-packages (from rich<14.0.0,>=10.11.0->typer[all]<0.10.0,>=0.9.0->langchain-cli->-r requirements.txt (line 8)) (3.0.0)
# Requirement already satisfied: ptyprocess in ./env/lib/python3.11/site-packages (from terminado>=0.8.3->jupyter-server->nbdime->-r requirements.txt (line 28)) (0.7.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in ./env/lib/python3.11/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain>=0.1.9->-r requirements.txt (line 1)) (1.0.0)
# Collecting argon2-cffi-bindings
#   Using cached argon2_cffi_bindings-21.2.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (86 kB)
# Requirement already satisfied: webencodings in ./env/lib/python3.11/site-packages (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server->nbdime->-r requirements.txt (line 28)) (0.5.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in ./env/lib/python3.11/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets<9,>=7.6->ipydatagrid->-r requirements.txt (line 23)) (0.8.3)
# Collecting fqdn
#   Downloading fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Collecting isoduration
#   Downloading isoduration-20.11.0-py3-none-any.whl (11 kB)
# Collecting uri-template
#   Downloading uri_template-1.3.0-py3-none-any.whl (11 kB)
# Collecting webcolors>=1.11
#   Downloading webcolors-1.13-py3-none-any.whl (14 kB)
# Requirement already satisfied: mdurl~=0.1 in ./env/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich<14.0.0,>=10.11.0->typer[all]<0.10.0,>=0.9.0->langchain-cli->-r requirements.txt (line 8)) (0.1.2)
# Requirement already satisfied: wcwidth in ./env/lib/python3.11/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets<9,>=7.6->ipydatagrid->-r requirements.txt (line 23)) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in ./env/lib/python3.11/site-packages (from stack-data->ipython>=6.1.0->ipywidgets<9,>=7.6->ipydatagrid->-r requirements.txt (line 23)) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in ./env/lib/python3.11/site-packages (from stack-data->ipython>=6.1.0->ipywidgets<9,>=7.6->ipydatagrid->-r requirements.txt (line 23)) (2.4.1)
# Requirement already satisfied: pure-eval in ./env/lib/python3.11/site-packages (from stack-data->ipython>=6.1.0->ipywidgets<9,>=7.6->ipydatagrid->-r requirements.txt (line 23)) (0.2.2)
# Collecting arrow>=0.15.0
#   Downloading arrow-1.3.0-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 2.6 MB/s eta 0:00:00
# Collecting types-python-dateutil>=2.8.10
#   Downloading types_python_dateutil-2.8.19.20240311-py3-none-any.whl (9.7 kB)
# Installing collected packages: webcolors, uri-template, types-python-dateutil, terminado, send2trash, rfc3986-validator, rfc3339-validator, python-json-logger, prometheus-client, fqdn, tiktoken, jupyter-server-terminals, arrow, argon2-cffi-bindings, isoduration, argon2-cffi, jupyter-events, jupyter-server, jupyter-server-mathjax, nbdime
#   Attempting uninstall: tiktoken
#     Found existing installation: tiktoken 0.6.0
#     Uninstalling tiktoken-0.6.0:
#       Successfully uninstalled tiktoken-0.6.0
# Successfully installed argon2-cffi-23.1.0 argon2-cffi-bindings-21.2.0 arrow-1.3.0 fqdn-1.5.1 isoduration-20.11.0 jupyter-events-0.9.1 jupyter-server-2.13.0 jupyter-server-mathjax-0.2.6 jupyter-server-terminals-0.5.3 nbdime-4.0.1 prometheus-client-0.20.0 python-json-logger-2.0.7 rfc3339-validator-0.1.4 rfc3986-validator-0.1.1 send2trash-1.8.2 terminado-0.18.1 tiktoken-0.5.2 types-python-dateutil-2.8.19.20240311 uri-template-1.3.0 webcolors-1.13
#
# [notice] A new release of pip available: 22.3.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import re
import sys
from langchain_openai import ChatOpenAI
from langchain.output_parsers import PydanticOutputParser
from langchain.prompts import PromptTemplate
from langchain.pydantic_v1 import BaseModel, Field
from langchain.tools import StructuredTool
from typing import List

model = ChatOpenAI(model_name="gpt-4-0125-preview", temperature=0)
application = "command line fibonacci calculator"
technology = "python"

# %%
# Create a featurelist for the tool we want to create
class Feature(BaseModel):
    feature: str = Field(description="The feature we want to create")
    description: str = Field(description="The description of the feature we want to create")

class Featurelist(BaseModel):
    features: List[Feature] = Field(description="A list of features we want to create")


feature_parser = PydanticOutputParser(pydantic_object=Featurelist)

# Create a prompt template for the tool we want to create
feature_prompt = PromptTemplate(
    template="I want to create a {application} using {technology}. Please give a short outline of which features should be implemented. .\n{format_instructions}\n",
    input_variables=["application", "technology"],
    partial_variables={"format_instructions": feature_parser.get_format_instructions()},
)

feature_chain = feature_prompt | model | feature_parser

def get_features(application: str, technology: str) -> Featurelist:
    """Provide a featurelist for a given application and technology"""
    features = feature_chain.invoke({"application": application,
                                    "technology": technology})
    return features

features = StructuredTool.from_function(get_features)

# %%
# create a directory structure for the tool we want to create
class File(BaseModel):
    path: str = Field(description="The path of the file")
    responsibility: str = Field(description="The responsibility of the file, what it should contain and what the responsibility")
    dependencies: List[str] = Field(description="The other files this file depends on")

class Files(BaseModel):
    files: List[File] = Field(description="A list of files we want to create")

file_parser = PydanticOutputParser(pydantic_object=Files)


directory_prompt = PromptTemplate(
    template="I want to create a {application} using {technology} with these features: {features}. List all the files that are needed and use this list to provide a file structure for this application. Describe what each file is responsible for and include supporting files like requirements.txt, README.md and setup files when needed: .\n{format_instructions}\n",
    input_variables=["application", "technology", "features"],
    partial_variables={"format_instructions": file_parser.get_format_instructions()},
)

def get_directory_structure(application: str, technology: str, features: Featurelist) -> Files:
    """Provide a file structure for a given application, technology and Features"""
    feature_list = ', '.join([feature.feature for feature in features.features])
    directory_chain = directory_prompt | model | file_parser
    directory_entries = directory_chain.invoke({"application": application,
                                                "technology": technology,
                                                "features": feature_list})
    return directory_entries

directory = StructuredTool.from_function(get_directory_structure)

# %%
# create all the files for the tool we want to create
base_dir = os.path.join(os.getcwd(), application + "/")
features = get_features(application, technology)
feature_list = ', '.join([feature.feature for feature in features.features])

directory_entries = get_directory_structure(application, technology, features)

files_to_create = directory_entries.files.copy()

code_prompt = PromptTemplate(
    template="I want to create a {application} using {technology} with these features: {features}. Please provide the contents for the file {file}, which is responsible for {responsibility}.  Please include inline documentation where needed. \n",
    input_variables=["application", "technology", "file", "responsibility", "features"],
)

code_chain = code_prompt | model
def get_code(application: str, technology: str, file: File, features: str) -> str:
    print(f"Getting code for file {file.path}")
    code = code_chain.invoke({"application": application,
                              "technology": technology,
                              "file": file.path,
                              "responsibility": file.responsibility,
                              "features": features})
    pattern = "```(.*?)(.+)```"
    result = re.search(pattern, code.content, re.DOTALL).group(2)

    print(f"Code for file {file.path} is {result}")
    sys.exit()
    return result


def create_file(file: File):
    print(f"Creating file {file.path}")
    for dependency in file.dependencies:
        print(f"Checking if dependency {dependency} exists")
        dependency_file = next((f for f in directory_entries.files if f.path == dependency), None)
        print(f"Creating dependency file {dependency_file.path} first")
        create_file(dependency_file)
    if not os.path.dirname(base_dir + file.path) == "":
        os.makedirs(os.path.dirname(base_dir + file.path), exist_ok=True)
    with open(base_dir + file.path, "w") as f:
        code = get_code(application, technology, file, feature_list)
        f.write(code)
        file_to_remove = next((f for f in files_to_create if f.path == file.path), None)
        if file_to_remove:
            files_to_create.remove(file_to_remove)

while len(files_to_create) > 0:
    create_file(files_to_create[0])
# Out:
# Creating file fibonacci_calculator.py
# Checking if dependency requirements.txt exists
# Creating dependency file requirements.txt first
# Creating file requirements.txt
# Getting code for file requirements.txt
# Code for file requirements.txt is
# # requirements.txt
#
# # For parsing command line arguments more efficiently than with sys.argv
# click==8.0.1
#
# # For performance optimization, you might consider using a library that
# # allows for caching results to speed up recursive functions.
# cachetools==4.2.2
#
# # For unit testing, pytest is a popular choice due to its powerful yet simple syntax.
# pytest==6.2.4
#
# # If your Fibonacci calculation or other parts of the program can benefit from
# # parallel execution to improve performance, consider including a library for that.
# # However, for a simple Fibonacci calculator, this might not be necessary.
#
# # Optional: If you're working with very large numbers and find Python's built-in
# # types insufficient, you might consider a library for arbitrary-precision arithmetic.
# # However, Python's built-in `int` type automatically handles large numbers well in most cases.
#
# # Documentation is crucial for maintaining and extending your project. Sphinx is a
# # tool that makes it easy to create intelligent and beautiful documentation.
# Sphinx==3.5.4
#
# # For better handling of asynchronous tasks, if your optimization strategies require it.
# # This is optional and based on your specific optimization approach.
# # asyncio
#
# # Note: The versions specified are current as of the knowledge cutoff date in 2023.
# # You may want to update these to the latest versions compatible with your Python environment.
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# /home/ksabass/Projects/langchain_agents/env/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3585: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
