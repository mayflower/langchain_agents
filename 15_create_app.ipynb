# %% [markdown]
# # Coding Assistant

# %%
# %pip install -r requirements.txt
# Out:
# Requirement already satisfied: langchain in /home/johann/anaconda3/envs/langchain_agents/lib/python3.11/site-packages (from -r requirements.txt (line 1)) (0.0.342)
# Requirement already satisfied: langchain-experimental in /home/johann/anaconda3/envs/langchain_agents/lib/python3.11/site-packages (from -r requirements.txt (line 2)) (0.0.43)
# Requirement already satisfied: langchainhub in /home/johann/anaconda3/envs/langchain_agents/lib/python3.11/site-packages (from -r requirements.txt (line 3)) (0.1.14)
# Requirement already satisfied: langchain-cli in /home/johann/anaconda3/envs/langchain_agents/lib/python3.11/site-packages (from -r requirements.txt (line 4)) (0.0.19)
# Requirement already satisfied: openai in /home/johann/anaconda3/envs/langchain_agents/lib/python3.11/site-packages (from -r requirements.txt (line 6)) (1.3.6)
# Requirement already satisfied: python-dotenv in /home/johann/anaconda3/envs/langchain_agents/lib/python3.11/site-packages (from -r requirements.txt (line 7)) (1.0.0)
# Requirement already satisfied: google-search-results in /home/johann/anaconda3/envs/langchain_agents/lib/python3.11/site-packages (from -r requirements.txt (line 8)) (2.4.2)
# Requirement already satisfied: faiss-cpu in /home/johann/anaconda3/envs/langchain_agents/lib/python3.11/site-packages (from -r requirements.txt (line 9)) (1.7.4)
# Requirement already satisfied: pypdf in /home/johann/anaconda3/envs/langchain_agents/lib/python3.11/site-packages (from -r requirements.txt (line 10)) (3.17.1)
# Requirement already satisfied: tqdm in /home/johann/anaconda3/envs/langchain_agents/lib/python3.11/site-packages (from -r requirements.txt (line 11)) (4.66.1)
# Requirement already satisfied: wikipedia in /home/johann/anaconda3/envs/langchain_agents/lib/python3.11/site-packages (from -r requirements.txt (line 12)) (1.4.0)
# Requirement already satisfied: arxiv in /home/johann/anaconda3/envs/langchain_agents/lib/python3.11/site-packages (from -r requirements.txt (line 13)) (2.0.0)
# Requirement already satisfied: atlassian-python-api in /home/johann/anaconda3/envs/langchain_agents/lib/python3.11/site-packages (from -r requirements.txt (line 14)) (3.41.4)
# Requirement already satisfied: numexpr in /home/johann/anaconda3/envs/langchain_agents/lib/python3.11/site-packages (from -r requirements.txt (line 15)) (2.8.7)
# Requirement already satisfied: beautifulsoup4 in /home/johann/anaconda3/envs/langchain_agents/lib/python3.11/site-packages (from -r requirements.txt (line 16)) (4.12.2)
# Requirement already satisfied: lxml in /home/johann/anaconda3/envs/langchain_agents/lib/python3.11/site-packages (from -r requirements.txt (line 17)) (4.9.3)
# Requirement already satisfied: tiktoken in /home/johann/anaconda3/envs/langchain_agents/lib/python3.11/site-packages (from -r requirements.txt (line 18)) (0.5.1)
# Requirement already satisfied: ipydatagrid in /home/johann/anaconda3/envs/langchain_agents/lib/python3.11/site-packages (from -r requirements.txt (line 19)) (1.2.0)
# Requirement already satisfied: bqplot in /home/johann/anaconda3/envs/langchain_agents/lib/python3.11/site-packages (from -r requirements.txt (line 20)) (0.12.42)
# Requirement already satisfied: langserve[all] in /home/johann/anaconda3/envs/langchain_agents/lib/python3.11/site-packages (from -r requirements.txt (line 5)) (0.0.32)
# Requirement already satisfied: PyYAML>=5.3 in /home/johann/anaconda3/envs/langchain_agents/lib/python3.11/site-packages (from langchain->-r requirements.txt (line 1)) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /home/johann/anaconda3/envs/langchain_agents/lib/python3.11/site-packages (from langchain->-r requirements.txt (line 1)) (2.0.23)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /home/johann/anaconda3/envs/langchain_agents/lib/python3.11/site-packages (from langchain->-r requirements.txt (line 1)) (3.9.1)
# Requirement already satisfied: anyio<4.0 in /home/johann/anaconda3/envs/langchain_agents/lib/python3.11/site-packages (from langchain->-r requirements.txt (line 1)) (3.7.1)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /home/johann/anaconda3/envs/langchain_agents/lib/python3.11/site-packages (from langchain->-r requirements.txt (line 1)) (0.6.3)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /home/johann/anaconda3/envs/langchain_agents/lib/python3.11/site-packages (from langchain->-r requirements.txt (line 1)) (1.33)
# Requirement already satisfied: langchain-core<0.1,>=0.0.7 in /home/johann/anaconda3/envs/langchain_agents/lib/python3.11/site-packages (from langchain->-r requirements.txt (line 1)) (0.0.7)
# Requirement already satisfied: langsmith<0.1.0,>=0.0.63 in /home/johann/anaconda3/envs/langchain_agents/lib/python3.11/site-packages (from langchain->-r requirements.txt (line 1)) (0.0.67)
# Requirement already satisfied: numpy<2,>=1 in /home/johann/anaconda3/envs/langchain_agents/lib/python3.11/site-packages (from langchain->-r requirements.txt (line 1)) (1.26.2)
# Requirement already satisfied: pydantic<3,>=1 in /home/johann/anaconda3/envs/langchain_agents/lib/python3.11/site-packages (from langchain->-r requirements.txt (line 1)) (2.5.2)
# Requirement already satisfied: requests<3,>=2 in /home/johann/anaconda3/envs/langchain_agents/lib/python3.11/site-packages (from langchain->-r requirements.txt (line 1)) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /home/johann/anaconda3/envs/langchain_agents/lib/python3.11/site-packages (from langchain->-r requirements.txt (line 1)) (8.2.3)
# Requirement already satisfied: types-requests<3.0.0.0,>=2.31.0.2 in /home/johann/anaconda3/envs/langchain_agents/lib/python3.11/site-packages (from langchainhub->-r requirements.txt (line 3)) (2.31.0.10)
# Requirement already satisfied: gitpython<4.0.0,>=3.1.40 in /home/johann/anaconda3/envs/langchain_agents/lib/python3.11/site-packages (from langchain-cli->-r requirements.txt (line 4)) (3.1.40)
# Requirement already satisfied: tomlkit<0.13.0,>=0.12.2 in /home/johann/anaconda3/envs/langchain_agents/lib/python3.11/site-packages (from langchain-cli->-r requirements.txt (line 4)) (0.12.3)
# Requirement already satisfied: typer<0.10.0,>=0.9.0 in /home/johann/anaconda3/envs/langchain_agents/lib/python3.11/site-packages (from typer[all]<0.10.0,>=0.9.0->langchain-cli->-r requirements.txt (line 4)) (0.9.0)
# Requirement already satisfied: uvicorn<0.24.0,>=0.23.2 in /home/johann/anaconda3/envs/langchain_agents/lib/python3.11/site-packages (from langchain-cli->-r requirements.txt (line 4)) (0.23.2)
# Requirement already satisfied: fastapi<1,>=0.90.1 in /home/johann/anaconda3/envs/langchain_agents/lib/python3.11/site-packages (from langserve[all]->-r requirements.txt (line 5)) (0.104.1)
# Requirement already satisfied: httpx>=0.23.0 in /home/johann/anaconda3/envs/langchain_agents/lib/python3.11/site-packages (from langserve[all]->-r requirements.txt (line 5)) (0.25.2)
# Requirement already satisfied: httpx-sse>=0.3.1 in /home/johann/anaconda3/envs/langchain_agents/lib/python3.11/site-packages (from langserve[all]->-r requirements.txt (line 5)) (0.3.1)
# Requirement already satisfied: orjson>=2 in /home/johann/anaconda3/envs/langchain_agents/lib/python3.11/site-packages (from langserve[all]->-r requirements.txt (line 5)) (3.9.10)
# Requirement already satisfied: sse-starlette<2.0.0,>=1.3.0 in /home/johann/anaconda3/envs/langchain_agents/lib/python3.11/site-packages (from langserve[all]->-r requirements.txt (line 5)) (1.8.2)
# Requirement already satisfied: distro<2,>=1.7.0 in /home/johann/anaconda3/envs/langchain_agents/lib/python3.11/site-packages (from openai->-r requirements.txt (line 6)) (1.8.0)
# Requirement already satisfied: sniffio in /home/johann/anaconda3/envs/langchain_agents/lib/python3.11/site-packages (from openai->-r requirements.txt (line 6)) (1.3.0)
# Requirement already satisfied: typing-extensions<5,>=4.5 in /home/johann/anaconda3/envs/langchain_agents/lib/python3.11/site-packages (from openai->-r requirements.txt (line 6)) (4.8.0)
# Requirement already satisfied: feedparser==6.0.10 in /home/johann/anaconda3/envs/langchain_agents/lib/python3.11/site-packages (from arxiv->-r requirements.txt (line 13)) (6.0.10)
# Requirement already satisfied: sgmllib3k in /home/johann/anaconda3/envs/langchain_agents/lib/python3.11/site-packages (from feedparser==6.0.10->arxiv->-r requirements.txt (line 13)) (1.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/johann/anaconda3/envs/langchain_agents/lib/python3.11/site-packages (from requests<3,>=2->langchain->-r requirements.txt (line 1)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/johann/anaconda3/envs/langchain_agents/lib/python3.11/site-packages (from requests<3,>=2->langchain->-r requirements.txt (line 1)) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/johann/anaconda3/envs/langchain_agents/lib/python3.11/site-packages (from requests<3,>=2->langchain->-r requirements.txt (line 1)) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/johann/anaconda3/envs/langchain_agents/lib/python3.11/site-packages (from requests<3,>=2->langchain->-r requirements.txt (line 1)) (2023.11.17)
# Requirement already satisfied: deprecated in /home/johann/anaconda3/envs/langchain_agents/lib/python3.11/site-packages (from atlassian-python-api->-r requirements.txt (line 14)) (1.2.14)
# Requirement already satisfied: six in /home/johann/anaconda3/envs/langchain_agents/lib/python3.11/site-packages (from atlassian-python-api->-r requirements.txt (line 14)) (1.16.0)
# Requirement already satisfied: oauthlib in /home/johann/anaconda3/envs/langchain_agents/lib/python3.11/site-packages (from atlassian-python-api->-r requirements.txt (line 14)) (3.2.2)
# Requirement already satisfied: requests-oauthlib in /home/johann/anaconda3/envs/langchain_agents/lib/python3.11/site-packages (from atlassian-python-api->-r requirements.txt (line 14)) (1.3.1)
# Requirement already satisfied: soupsieve>1.2 in /home/johann/anaconda3/envs/langchain_agents/lib/python3.11/site-packages (from beautifulsoup4->-r requirements.txt (line 16)) (2.5)
# Requirement already satisfied: regex>=2022.1.18 in /home/johann/anaconda3/envs/langchain_agents/lib/python3.11/site-packages (from tiktoken->-r requirements.txt (line 18)) (2023.10.3)
# Requirement already satisfied: ipywidgets<9,>=7.6 in /home/johann/anaconda3/envs/langchain_agents/lib/python3.11/site-packages (from ipydatagrid->-r requirements.txt (line 19)) (8.1.1)
# Requirement already satisfied: pandas>=1.3.5 in /home/johann/anaconda3/envs/langchain_agents/lib/python3.11/site-packages (from ipydatagrid->-r requirements.txt (line 19)) (2.1.3)
# Requirement already satisfied: py2vega>=0.5 in /home/johann/anaconda3/envs/langchain_agents/lib/python3.11/site-packages (from ipydatagrid->-r requirements.txt (line 19)) (0.6.1)
# Requirement already satisfied: traitlets>=4.3.0 in /home/johann/anaconda3/envs/langchain_agents/lib/python3.11/site-packages (from bqplot->-r requirements.txt (line 20)) (5.14.0)
# Requirement already satisfied: traittypes>=0.0.6 in /home/johann/anaconda3/envs/langchain_agents/lib/python3.11/site-packages (from bqplot->-r requirements.txt (line 20)) (0.2.1)
# Requirement already satisfied: attrs>=17.3.0 in /home/johann/anaconda3/envs/langchain_agents/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain->-r requirements.txt (line 1)) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/johann/anaconda3/envs/langchain_agents/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain->-r requirements.txt (line 1)) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/johann/anaconda3/envs/langchain_agents/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain->-r requirements.txt (line 1)) (1.9.3)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/johann/anaconda3/envs/langchain_agents/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain->-r requirements.txt (line 1)) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/johann/anaconda3/envs/langchain_agents/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain->-r requirements.txt (line 1)) (1.3.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /home/johann/anaconda3/envs/langchain_agents/lib/python3.11/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain->-r requirements.txt (line 1)) (3.20.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /home/johann/anaconda3/envs/langchain_agents/lib/python3.11/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain->-r requirements.txt (line 1)) (0.9.0)
# Requirement already satisfied: starlette<0.28.0,>=0.27.0 in /home/johann/anaconda3/envs/langchain_agents/lib/python3.11/site-packages (from fastapi<1,>=0.90.1->langserve[all]->-r requirements.txt (line 5)) (0.27.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/johann/anaconda3/envs/langchain_agents/lib/python3.11/site-packages (from gitpython<4.0.0,>=3.1.40->langchain-cli->-r requirements.txt (line 4)) (4.0.11)
# Requirement already satisfied: httpcore==1.* in /home/johann/anaconda3/envs/langchain_agents/lib/python3.11/site-packages (from httpx>=0.23.0->langserve[all]->-r requirements.txt (line 5)) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/johann/anaconda3/envs/langchain_agents/lib/python3.11/site-packages (from httpcore==1.*->httpx>=0.23.0->langserve[all]->-r requirements.txt (line 5)) (0.14.0)
# Requirement already satisfied: comm>=0.1.3 in /home/johann/anaconda3/envs/langchain_agents/lib/python3.11/site-packages (from ipywidgets<9,>=7.6->ipydatagrid->-r requirements.txt (line 19)) (0.2.0)
# Requirement already satisfied: ipython>=6.1.0 in /home/johann/anaconda3/envs/langchain_agents/lib/python3.11/site-packages (from ipywidgets<9,>=7.6->ipydatagrid->-r requirements.txt (line 19)) (8.18.1)
# Requirement already satisfied: widgetsnbextension~=4.0.9 in /home/johann/anaconda3/envs/langchain_agents/lib/python3.11/site-packages (from ipywidgets<9,>=7.6->ipydatagrid->-r requirements.txt (line 19)) (4.0.9)
# Requirement already satisfied: jupyterlab-widgets~=3.0.9 in /home/johann/anaconda3/envs/langchain_agents/lib/python3.11/site-packages (from ipywidgets<9,>=7.6->ipydatagrid->-r requirements.txt (line 19)) (3.0.9)
# Requirement already satisfied: jsonpointer>=1.9 in /home/johann/anaconda3/envs/langchain_agents/lib/python3.11/site-packages (from jsonpatch<2.0,>=1.33->langchain->-r requirements.txt (line 1)) (2.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/johann/anaconda3/envs/langchain_agents/lib/python3.11/site-packages (from pandas>=1.3.5->ipydatagrid->-r requirements.txt (line 19)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/johann/anaconda3/envs/langchain_agents/lib/python3.11/site-packages (from pandas>=1.3.5->ipydatagrid->-r requirements.txt (line 19)) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /home/johann/anaconda3/envs/langchain_agents/lib/python3.11/site-packages (from pandas>=1.3.5->ipydatagrid->-r requirements.txt (line 19)) (2023.3)
# Requirement already satisfied: gast<0.5,>=0.4.0 in /home/johann/anaconda3/envs/langchain_agents/lib/python3.11/site-packages (from py2vega>=0.5->ipydatagrid->-r requirements.txt (line 19)) (0.4.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /home/johann/anaconda3/envs/langchain_agents/lib/python3.11/site-packages (from pydantic<3,>=1->langchain->-r requirements.txt (line 1)) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.5 in /home/johann/anaconda3/envs/langchain_agents/lib/python3.11/site-packages (from pydantic<3,>=1->langchain->-r requirements.txt (line 1)) (2.14.5)
# Requirement already satisfied: greenlet!=0.4.17 in /home/johann/anaconda3/envs/langchain_agents/lib/python3.11/site-packages (from SQLAlchemy<3,>=1.4->langchain->-r requirements.txt (line 1)) (3.0.1)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /home/johann/anaconda3/envs/langchain_agents/lib/python3.11/site-packages (from typer<0.10.0,>=0.9.0->typer[all]<0.10.0,>=0.9.0->langchain-cli->-r requirements.txt (line 4)) (8.1.7)
# Requirement already satisfied: colorama<0.5.0,>=0.4.3 in /home/johann/anaconda3/envs/langchain_agents/lib/python3.11/site-packages (from typer[all]<0.10.0,>=0.9.0->langchain-cli->-r requirements.txt (line 4)) (0.4.6)
# Requirement already satisfied: shellingham<2.0.0,>=1.3.0 in /home/johann/anaconda3/envs/langchain_agents/lib/python3.11/site-packages (from typer[all]<0.10.0,>=0.9.0->langchain-cli->-r requirements.txt (line 4)) (1.5.4)
# Requirement already satisfied: rich<14.0.0,>=10.11.0 in /home/johann/anaconda3/envs/langchain_agents/lib/python3.11/site-packages (from typer[all]<0.10.0,>=0.9.0->langchain-cli->-r requirements.txt (line 4)) (13.7.0)
# Requirement already satisfied: wrapt<2,>=1.10 in /home/johann/anaconda3/envs/langchain_agents/lib/python3.11/site-packages (from deprecated->atlassian-python-api->-r requirements.txt (line 14)) (1.16.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/johann/anaconda3/envs/langchain_agents/lib/python3.11/site-packages (from gitdb<5,>=4.0.1->gitpython<4.0.0,>=3.1.40->langchain-cli->-r requirements.txt (line 4)) (5.0.1)
# Requirement already satisfied: decorator in /home/johann/anaconda3/envs/langchain_agents/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6->ipydatagrid->-r requirements.txt (line 19)) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/johann/anaconda3/envs/langchain_agents/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6->ipydatagrid->-r requirements.txt (line 19)) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /home/johann/anaconda3/envs/langchain_agents/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6->ipydatagrid->-r requirements.txt (line 19)) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /home/johann/anaconda3/envs/langchain_agents/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6->ipydatagrid->-r requirements.txt (line 19)) (3.0.41)
# Requirement already satisfied: pygments>=2.4.0 in /home/johann/anaconda3/envs/langchain_agents/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6->ipydatagrid->-r requirements.txt (line 19)) (2.17.2)
# Requirement already satisfied: stack-data in /home/johann/anaconda3/envs/langchain_agents/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6->ipydatagrid->-r requirements.txt (line 19)) (0.6.3)
# Requirement already satisfied: pexpect>4.3 in /home/johann/anaconda3/envs/langchain_agents/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6->ipydatagrid->-r requirements.txt (line 19)) (4.9.0)
# Requirement already satisfied: packaging>=17.0 in /home/johann/anaconda3/envs/langchain_agents/lib/python3.11/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json<0.7,>=0.5.7->langchain->-r requirements.txt (line 1)) (23.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/johann/anaconda3/envs/langchain_agents/lib/python3.11/site-packages (from rich<14.0.0,>=10.11.0->typer[all]<0.10.0,>=0.9.0->langchain-cli->-r requirements.txt (line 4)) (3.0.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /home/johann/anaconda3/envs/langchain_agents/lib/python3.11/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain->-r requirements.txt (line 1)) (1.0.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /home/johann/anaconda3/envs/langchain_agents/lib/python3.11/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets<9,>=7.6->ipydatagrid->-r requirements.txt (line 19)) (0.8.3)
# Requirement already satisfied: mdurl~=0.1 in /home/johann/anaconda3/envs/langchain_agents/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich<14.0.0,>=10.11.0->typer[all]<0.10.0,>=0.9.0->langchain-cli->-r requirements.txt (line 4)) (0.1.2)
# Requirement already satisfied: ptyprocess>=0.5 in /home/johann/anaconda3/envs/langchain_agents/lib/python3.11/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets<9,>=7.6->ipydatagrid->-r requirements.txt (line 19)) (0.7.0)
# Requirement already satisfied: wcwidth in /home/johann/anaconda3/envs/langchain_agents/lib/python3.11/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets<9,>=7.6->ipydatagrid->-r requirements.txt (line 19)) (0.2.12)
# Requirement already satisfied: executing>=1.2.0 in /home/johann/anaconda3/envs/langchain_agents/lib/python3.11/site-packages (from stack-data->ipython>=6.1.0->ipywidgets<9,>=7.6->ipydatagrid->-r requirements.txt (line 19)) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /home/johann/anaconda3/envs/langchain_agents/lib/python3.11/site-packages (from stack-data->ipython>=6.1.0->ipywidgets<9,>=7.6->ipydatagrid->-r requirements.txt (line 19)) (2.4.1)
# Requirement already satisfied: pure-eval in /home/johann/anaconda3/envs/langchain_agents/lib/python3.11/site-packages (from stack-data->ipython>=6.1.0->ipywidgets<9,>=7.6->ipydatagrid->-r requirements.txt (line 19)) (0.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import re
import sys
from langchain.chat_models import AzureChatOpenAI
from langchain.output_parsers import PydanticOutputParser
from langchain.prompts import PromptTemplate
from langchain.pydantic_v1 import BaseModel, Field, validator
from langchain.tools import StructuredTool
from typing import List
from enum import Enum, IntEnum

model =AzureChatOpenAI(deployment_name="gpt-4-32k", temperature=0)
application = "command line fibonacci calculator"
technology = "python"

# %%
# Create a featurelist for the tool we want to create
class Feature(BaseModel):
    feature: str = Field(description="The feature we want to create")
    description: str = Field(description="The description of the feature we want to create")

class Featurelist(BaseModel):
    features: List[Feature] = Field(description="A list of features we want to create")


feature_parser = PydanticOutputParser(pydantic_object=Featurelist)

# Create a prompt template for the tool we want to create
feature_prompt = PromptTemplate(
    template="I want to create a {application} using {technology}. Please give a short outline of which features should be implemented. .\n{format_instructions}\n",
    input_variables=["application", "technology"],
    partial_variables={"format_instructions": feature_parser.get_format_instructions()},
)

feature_chain = feature_prompt | model | feature_parser

def get_features(application: str, technology: str) -> Featurelist:
    """Provide a featurelist for a given application and technology"""
    features = feature_chain.invoke({"application": application, 
                                    "technology": technology})
    return features

features = StructuredTool.from_function(get_features)

# %%
# create a directory structure for the tool we want to create
class File(BaseModel):
    path: str = Field(description="The path of the file")
    responsibility: str = Field(description="The responsibility of the file, what it should contain and what the responsibility")
    dependencies: List[str] = Field(description="The other files this file depends on")

class Files(BaseModel):
    files: List[File] = Field(description="A list of files we want to create")

file_parser = PydanticOutputParser(pydantic_object=Files) 


directory_prompt = PromptTemplate(
    template="I want to create a {application} using {technology} with these features: {features}. List all the files that are needed and use this list to provide a file structure for this application. Describe what each file is responsible for and include supporting files like requirements.txt, README.md and setup files when needed: .\n{format_instructions}\n",
    input_variables=["application", "technology", "features"],
    partial_variables={"format_instructions": file_parser.get_format_instructions()},
)

def get_directory_structure(application: str, technology: str, features: Featurelist) -> Files:
    """Provide a file structure for a given application, technology and Features"""
    feature_list = ', '.join([feature.feature for feature in features.features])
    directory_chain = directory_prompt | model | file_parser
    directory_entries = directory_chain.invoke({"application": application, 
                                                "technology": technology,
                                                "features": feature_list})
    return directory_entries

directory = StructuredTool.from_function(get_directory_structure)

# %%
# create all the files for the tool we want to create
base_dir = os.path.join(os.getcwd(), application + "/")
features = get_features(application, technology)
feature_list = ', '.join([feature.feature for feature in features.features])

directory_entries = get_directory_structure(application, technology, features)

files_to_create = directory_entries.files.copy()    

code_prompt = PromptTemplate(
    template="I want to create a {application} using {technology} with these features: {features}. Please provide the contents for the file {file}, which is responsible for {responsibility}.  Please include inline documentation where needed. \n",
    input_variables=["application", "technology", "file", "responsibility", "features"],
)

code_chain = code_prompt | model
def get_code(application: str, technology: str, file: File, features: str) -> str:
    print(f"Getting code for file {file.path}")
    code = code_chain.invoke({"application": application,
                              "technology": technology,
                              "file": file.path,
                              "responsibility": file.responsibility,
                              "features": features})
    pattern = "```(.*?)(.+)```"    
    result = re.search(pattern, code.content, re.DOTALL).group(2)

    print(f"Code for file {file.path} is {result}")    
    sys.exit()
    return result


def create_file(file: File):
    print(f"Creating file {file.path}")
    for dependency in file.dependencies:
        print(f"Checking if dependency {dependency} exists")        
        dependency_file = next((f for f in directory_entries.files if f.path == dependency), None)
        print(f"Creating dependency file {dependency_file.path} first")
        create_file(dependency_file)
    if not os.path.dirname(base_dir + file.path) == "":
        os.makedirs(os.path.dirname(base_dir + file.path), exist_ok=True)
    with open(base_dir + file.path, "w") as f:
        code = get_code(application, technology, file, feature_list)
        f.write(code)
        file_to_remove = next((f for f in files_to_create if f.path == file.path), None)
        if file_to_remove:
            files_to_create.remove(file_to_remove)

while len(files_to_create) > 0:
    create_file(files_to_create[0])
# Out:
# Creating file README.md
# Getting code for file README.md
# Code for file README.md is <re.Match object; span=(2105, 2179), match='```json\n{\n    "0": 0,\n    "1": 1,\n    "2": 1,>
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# /home/johann/anaconda3/envs/bahn/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3558: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
